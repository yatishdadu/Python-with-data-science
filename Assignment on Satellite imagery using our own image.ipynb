# %%
# %matplotlib inline
import numpy as np
from scipy import misc
import matplotlib.pyplot as plt

# %%
from skimage import data

photo_mix = misc.imread('C:/Users/yatis/Downloads/datascience/numpy/assignment/p.jpg')

type(photo_mix)
# Out:
# C:\Users\yatis\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# numpy.ndarray

# %%
plt.figure(figsize=(15,15))
plt.imshow(photo_mix)

# %%
photo_mix.shape
# Out:
# (1080, 1920, 3)

# %%
photo_mix.size
# Out:
# 6220800

# %%
photo_mix.mean()
# Out:
# 194.69734069573045

# %%
photo_mix.min(),photo_mix.max()
# Out:
# (0, 255)

# %%
photo_mix[150,250]
# Out:
# array([211, 223, 239], dtype=uint8)

# %%
photo_mix[150,250,1]
# Out:
# 223

# %%
photo_mix[150,250]=0
plt.figure(figsize=(10,10))
plt.imshow(photo_mix)

# %%
photo_mix = misc.imread('C:/Users/yatis/Downloads/datascience/numpy/assignment/p.jpg')
photo_mix[200:800,:,1]=250
plt.figure(figsize=(10,10))
plt.imshow(photo_mix)
# Out:
# C:\Users\yatis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
